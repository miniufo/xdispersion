# %% [markdown]
# ## 05. More statistics
# **21 March 2025 by MiniUFO**
#
# ---
# [TOC]
#
# ---
# ### 1. Introduction
# Previously, we have shown how to calculate the relative dispersion.  Here we are going to show more dispersion measures, like kurtosis, which is also a time-based measure.  In addition, we also calculate some of the separation-based measures.
#
# ---
#
# ### 2. Calculation
# #### 2.1 load the GLAD dataset and get original pairs

# %%
import numpy as np
import xarray as xr
import sys
sys.path.append('../../../')
from xdispersion import RelativeDispersion

drifters = xr.open_dataset('../../../data/glad32.nc')

rd = RelativeDispersion(drifters, maxtlen=4*24*85, ragged=True, ID='traj',
                        xpos='longitude', uvel='ve', time='time', Rearth=6371.2,
                        ypos='latitude' , vvel='vn', coord='latlon')

pairs = rd.get_all_pairs()

# filter original pairs from all pairs
origin_pairs = rd.get_original_pairs(pairs, r0=[0.08, 0.18])
origin_pairs
# Out:
# there are 43518 pairs of particles
# <xarray.Dataset> Size: 10kB
# Dimensions:   (pair: 171, particle: 2)
# Coordinates:
#   * pair      (pair) int32 684B 5716 6266 6539 7083 ... 43389 43396 43425 43463
#   * particle  (particle) int32 8B 0 1
# Data variables:
#     tlen      (pair) int32 684B 3557 3142 3759 1999 3661 ... 1314 4296 8039 3514
#     stim      (pair) datetime64[ns] 1kB 2012-07-22T12:45:00 ... 2012-07-22T16...
#     r0        (pair) float32 684B 0.08872 0.18 0.09602 ... 0.09732 0.08311
#     pID       (pair, particle) int32 1kB 20 21 22 23 23 ... 281 282 283 285 286
#     xpos0     (pair, particle) float32 1kB -88.2 -88.2 -88.2 ... -88.09 -88.08
#     ypos0     (pair, particle) float32 1kB 28.8 28.8 28.8 ... 27.89 28.84 28.84
#     idxI      (pair, particle) int32 1kB 121691 125248 ... 1556133 1559647
#     idxJ      (pair, particle) int32 1kB 130550 134107 ... 1559647 1563161

# %% [markdown]
# #### 2.2 Extract building blocks for various measures
# There are some basic separation and velocity measures, which serves as building blocks for calculating dispersion measures.  First we get all these building blocks.  These measures are of the same shape (`pair: 171, rtime: 8160`).

# %%
rx, ry, rxy, r, rpb = rd.separation_measures(origin_pairs) # separations of different components
du, dv, dul, dut, vmi, vmj, uv = rd.velocity_measures(origin_pairs) # velocities of different components

print(r)
# Out:
# <xarray.DataArray (pair: 171, rtime: 8160)> Size: 6MB
# array([[0.0887171 , 0.0925243 , 0.09182951, ...,        nan,        nan,
#                nan],
#        [0.17996077, 0.17146686, 0.16548474, ...,        nan,        nan,
#                nan],
#        [0.09601758, 0.08657049, 0.07783855, ...,        nan,        nan,
#                nan],
#        ...,
#        [0.12593399, 0.14776982, 0.16553256, ...,        nan,        nan,
#                nan],
#        [0.09731857, 0.09452672, 0.09233715, ...,        nan,        nan,
#                nan],
#        [0.08311204, 0.09666245, 0.10717935, ...,        nan,        nan,
#                nan]], shape=(171, 8160), dtype=float32)
# Coordinates:
#   * pair     (pair) int32 684B 5716 6266 6539 7083 ... 43389 43396 43425 43463
#   * rtime    (rtime) float64 65kB 0.0 0.01042 0.02083 ... 84.97 84.98 84.99

# %% [markdown]
# #### 2.3 Calculate time-based measures using `xdisperison.measures`

# %% [markdown]
# Now we could calculate many measures using `xdispersion.measures`.  This wraps the calculation and bootstrapping into a single function call.  First for time-based measures, which are eventually plotted against time.

# %%
from xdispersion.measures import *

mean_at = 'const-t'

r2_t   = relative_dispersion(r, order=2, mean_at=mean_at)
S2_t   = velocity_structure_function(np.hypot(du, dv), r, mean_at=mean_at)
S2ll_t = velocity_structure_function(dul, r, mean_at=mean_at)
S2tr_t = velocity_structure_function(dut, r, mean_at=mean_at)
S3_t   = velocity_structure_function(dul*(du**2+dv**2), r, order=1, mean_at=mean_at)
ku_t   = kurtosis(r, mean_at=mean_at)
cve_t  = cencini_vulpiani_exponent(r, mean_at=mean_at)

# %% [markdown]
# Now we can plot the kurtosis, and see an overshoot which may be an indicator of nonlocal (Lundgren) dispersion behavior.

# %%
ku_t.plot(xscale='log', figsize=(6, 3))

# %% [markdown]
# Note that we could bootstrapping by specifying a positive `ensemble` keyward argument.  By default, it is zero, which means no bootstrapping.  If it is set to a positive integer, boostrapping will be done and lower and upper bounds of errorbar will be returned.

# %%
ku_t, lower, upper = kurtosis(r, mean_at=mean_at, ensemble=1000)

# %%
import matplotlib.pyplot as plt

ku_t.plot(xscale='log', figsize=(6, 3), c='b')
plt.fill_between(ku_t.rtime, lower, upper, alpha=0.2, color='b')

# %% [markdown]
# #### 2.4 Calculate separation-based measures using `xdisperison.measures`

# %% [markdown]
# All measures can be averaged at constant separation, instead of time.  These are then separation-based measures.

# %%
from xdispersion.measures import *
from xdispersion.utils import gen_rbins

mean_at = 'const-r'
# generate a set of separation bins rbins(n) = r0 * alpha**n
rbins = gen_rbins(0.01, 1000, alpha=1.2)

r2_r   = relative_dispersion(r, order=2, mean_at=mean_at, rbins=rbins)
S2_r   = velocity_structure_function(np.hypot(du, dv), r, mean_at=mean_at, rbins=rbins)
S2ll_r = velocity_structure_function(dul, r, mean_at=mean_at, rbins=rbins)
S2tr_r = velocity_structure_function(dut, r, mean_at=mean_at, rbins=rbins)
S3_r   = velocity_structure_function(dul*(du**2+dv**2), r, order=1, mean_at=mean_at, rbins=rbins)
ku_r   = kurtosis(r, mean_at=mean_at, rbins=rbins)

# %% [markdown]
# Note that `r2_r` and `ku_r` are trival when averaged at constant separation `r`.  Now we plot the velocity structure functions.

# %%
import matplotlib.pyplot as plt

m1 = S2_r.plot.line(xscale='log', yscale='log', figsize=(6,3.5), marker='o', color='r', markersize=2, lw=0.5, zorder=1, label='total S2')
m2 = S2ll_r.plot(marker='o', color='b', markersize=2, lw=0.5, zorder=1, label='longitudinal S2')
m3 = S2tr_r.plot(marker='o', color='g', markersize=2, lw=0.5, zorder=1, label='transversal S2')
plt.legend([m1[0].get_label(), m2[0].get_label(), m3[0].get_label()], loc='lower right')
plt.title('velocity structure functions')
plt.xlabel('r-bin (km)')
_ = plt.ylabel('variance (m$^2$ s$^{-2}$)')

# %% [markdown]
# We could also decompose the structure function into rotational and divergent components:

# %%
from xdispersion import rotational_divergent_components

S2rr, S2dd = rotational_divergent_components(S2ll_r, S2tr_r)

# %% [markdown]
# Plot this decomposition.

# %%
import matplotlib.pyplot as plt

m1 = S2_r.plot.line(xscale='log', yscale='log', figsize=(6,3.5), marker='o', color='r', markersize=2, lw=0.5, zorder=1, label='total S2')
m2 = S2rr.plot(marker='o', color='b', markersize=2, lw=0.5, zorder=1, label='rotational S2')
m3 = S2dd.plot(marker='o', color='g', markersize=2, lw=0.5, zorder=1, label='divergent S2')
plt.legend([m1[0].get_label(), m2[0].get_label(), m3[0].get_label()], loc='upper left')
plt.title('velocity structure functions')
plt.xlabel('r-bin (km)')
_ = plt.ylabel('variance (m$^2$ s$^{-2}$)')

# %%
FAGR_r, upper, lower = finite_amplitude_growth_rate(r, mean_at=mean_at, rbins=rbins,
                                                    ensemble=1000, samples='all')
FAGRp_r, upperp, lowerp = finite_amplitude_growth_rate(r, mean_at=mean_at, rbins=rbins,
                                                    ensemble=1000, samples='positive')
# Out:
# /home/qianyk/miniconda3/envs/py13/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:818: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/qianyk/miniconda3/envs/py13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:1298: RuntimeWarning: invalid value encountered in multiply
#   out[tuple(slice1)] = a * f[tuple(slice2)] + b * f[tuple(slice3)] + c * f[tuple(slice4)]
# /home/qianyk/miniconda3/envs/py13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:1298: RuntimeWarning: invalid value encountered in add
#   out[tuple(slice1)] = a * f[tuple(slice2)] + b * f[tuple(slice3)] + c * f[tuple(slice4)]
# /home/qianyk/miniconda3/envs/py13/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:818: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/qianyk/miniconda3/envs/py13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:1298: RuntimeWarning: invalid value encountered in multiply
#   out[tuple(slice1)] = a * f[tuple(slice2)] + b * f[tuple(slice3)] + c * f[tuple(slice4)]
# /home/qianyk/miniconda3/envs/py13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:1298: RuntimeWarning: invalid value encountered in add
#   out[tuple(slice1)] = a * f[tuple(slice2)] + b * f[tuple(slice3)] + c * f[tuple(slice4)]

# %%
import matplotlib.pyplot as plt

m1 = FAGR_r.plot.line(xscale='log', yscale='log', figsize=(6,3.5), marker='o', color='r', markersize=2, lw=0.5, zorder=1, label='FAGR')
m2 = FAGRp_r.plot.line(marker='o', color='b', markersize=2, lw=0.5, zorder=1, label='FAGRp')
plt.fill_between(FAGR_r.rbin, upper, lower, alpha=0.2, color='r', zorder=-5)
plt.fill_between(FAGRp_r.rbin, upperp, lowerp, alpha=0.2, color='b', zorder=-5)
plt.legend([m1[0].get_label(), m2[0].get_label()], loc='upper right')
plt.title('FAGR')
plt.xlabel('r-bin (km)')
_ = plt.ylabel('FAGR (day$^{-1}$)')

# %% [markdown]
# ### 3. Conclusions
#
# The time-based and separation-based measures are generally not the same, as they are averaged at constant time and constant separation, respectively.
